# %%
import datetime
print(datetime.datetime.now())
# Out:
# 2020-07-18 12:12:00.956683

# %%
import pandas as pd
import numpy as np

# %%
cnoc_test = pd.read_csv('/c/Users/rick_/Google Drive/E.Personal/MCUR/Projects/P04.cnoc/cnoc-test.csv')

# %%
cnoc_test.head()
# Out:
#          time-reported mac-label        mac-address           location  \
# 0  2020-07-18 10:20:23      MAC1  CC:46:D6:00:01:02  Boulder, Colorado
# 1  2020-07-18 10:20:23      MAC2  3C:5A:B4:10:20:30  Boulder, Colorado
# 2  2020-07-20 10:20:23      MAC3  3C:D9:2B:10:30:40  Boulder, Colorado
# 3  2020-07-21 10:20:23      MAC4  00:9A:CD:40:50:60  Boulder, Colorado
# 4  2020-07-22 10:20:23      MAC5  98:5f:d3:3d:f9:c4  Boulder, Colorado
#
#    latitude  longitude
# 0   40.0274  -105.2519
# 1   41.0274  -104.2519
# 2   42.0274  -103.2519
# 3   43.0274  -102.2519
# 4   44.0274  -101.2519

# %%
cnoc_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time-reported  55 non-null     object
#  1   mac-label      12 non-null     object
#  2   mac-address    55 non-null     object
#  3   location       55 non-null     object
#  4   latitude       55 non-null     float64
#  5   longitude      55 non-null     float64
# dtypes: float64(2), object(4)
# memory usage: 2.7+ KB

# %%
import datetime

# %%
cnoc_test.corr()
# Out:
#            latitude  longitude
# latitude   1.000000   0.226728
# longitude  0.226728   1.000000

# %%
cnoc_test["Date"]= pd.to_datetime(cnoc_test["time-reported"])

# %%
cnoc_test.set_index('Date')
# Out:
#                            time-reported mac-label        mac-address  \
# Date
# 2020-07-18 10:20:23  2020-07-18 10:20:23      MAC1  CC:46:D6:00:01:02
# 2020-07-18 10:20:23  2020-07-18 10:20:23      MAC2  3C:5A:B4:10:20:30
# 2020-07-20 10:20:23  2020-07-20 10:20:23      MAC3  3C:D9:2B:10:30:40
# 2020-07-21 10:20:23  2020-07-21 10:20:23      MAC4  00:9A:CD:40:50:60
# 2020-07-22 10:20:23  2020-07-22 10:20:23      MAC5  98:5f:d3:3d:f9:c4
# 2020-07-21 10:20:23  2020-07-21 10:20:23      MAC2  3C:5A:B4:10:20:30
# 2020-07-22 10:20:23  2020-07-22 10:20:23      MAC3  3C:D9:2B:10:30:40
# 2020-07-21 10:20:23  2020-07-21 10:20:23      MAC4  00:9A:CD:40:50:60
# 2020-07-20 10:20:23  2020-07-20 10:20:23      MAC1  CC:46:D6:00:01:02
# 2020-07-20 10:20:23  2020-07-20 10:20:23      MAC3  3C:D9:2B:10:30:40
# 2020-07-22 10:20:23  2020-07-22 10:20:23       NaN  00:15:5d:35:d2:84
# 2020-07-23 10:20:23  2020-07-23 10:20:23       NaN  00:ff:67:6c:3a:d9
# ...

# %%
cnoc_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   time-reported  55 non-null     object
#  1   mac-label      12 non-null     object
#  2   mac-address    55 non-null     object
#  3   location       55 non-null     object
#  4   latitude       55 non-null     float64
#  5   longitude      55 non-null     float64
#  6   Date           55 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(4)
# memory usage: 3.1+ KB

# %%
cnoc_test['latitude'].round(3)
# Out:
# 0     40.027
# 1     41.027
# 2     42.027
# 3     43.027
# 4     44.027
# 5     45.027
# 6     46.027
# 7     47.027
# 8     59.950
# 9     59.950
# 10    60.950
# 11    61.950
# 12    62.950
# 13    63.950
# 14    39.617
# 15    39.617
# 16    44.027
# 17    45.027
# 18    46.027
# 19    47.027
# 20    48.027
# 21    49.027
# 22    50.027
# 23    51.027
# 24    52.027
# 25    53.027
# 26    54.027
# 27    55.027
# 28    56.027
# 29    57.027
# 30    58.027
# 31    59.027
# 32    60.027
# 33    61.027
# 34    62.027
# 35    63.027
# 36    64.027
# 37    65.027
# 38    66.027
# 39    67.027
# 40    68.027
# 41    69.027
# 42    70.027
# 43    71.027
# 44    72.027
# 45    73.027
# 46    74.027
# 47    75.027
# 48    76.027
# 49    77.027
# 50    78.027
# 51    79.027
# 52    80.027
# 53    81.027
# 54    82.027
# Name: latitude, dtype: float64

# %%
block_of_time = pd.date_range('2020-06-08 18:15:05', periods=400, freq='s')

# %%
block_of_time[200]
# Out:
# Timestamp('2020-06-08 18:18:25', freq='S')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-054be1c8ef4c> in <module>
# ----> 1 block_of_time.describe()
#
# AttributeError: 'DatetimeIndex' object has no attribute 'describe'
